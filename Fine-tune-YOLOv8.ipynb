# %% [markdown]
# # Run on Google Colab using GPU
#
# ### Folder structure for PreparedData
#
# ```
# PreparedData/
# ├── images/
# │   ├── train/    00000.jpg
# │   ├── val/
# │   └── test/
# ├── labels/
# │   ├── train/    00000.txt    format: <class_id> <x_center> <y_center> <width>
# │   ├── val/
# │   └── test/
# └── traffic_sign.yaml
# ```

# %%
# !nvidia-smi
# Out:
# Mon Jul 28 19:02:09 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   58C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/drive/MyDrive/GTSDB.zip /content/

# %%
# !unzip /content/GTSDB.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: PreparedData/labels/train/01105.txt
#   inflating: PreparedData/labels/train/01106.txt
#   inflating: PreparedData/labels/train/01107.txt
#   inflating: PreparedData/labels/train/01108.txt
#   inflating: PreparedData/labels/train/01109.txt
#   inflating: PreparedData/labels/train/01110.txt
#   inflating: PreparedData/labels/train/01111.txt
#   inflating: PreparedData/labels/train/01112.txt
#   inflating: PreparedData/labels/train/01113.txt
#   inflating: PreparedData/labels/train/01114.txt
#   inflating: PreparedData/labels/train/01115.txt
#   inflating: PreparedData/labels/train/01116.txt
#   inflating: PreparedData/labels/train/01121.txt
#   inflating: PreparedData/labels/train/01122.txt
#   inflating: PreparedData/labels/train/01123.txt
#   inflating: PreparedData/labels/train/01124.txt
#   inflating: PreparedData/labels/train/01125.txt
#   inflating: PreparedData/labels/train/01126.txt
# ...

# %%
# !cp /content/GTSDB/traffic_sign.yaml /content/

# %%
# !pip install ultralytics

# %%
# !pwd
# Out:
# /content

# %%
# !yolo detect train model=yolov8n.pt data=traffic_sign.yaml epochs=30 imgsz=640 batch=16
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100% 6.25M/6.25M [00:00<00:00, 411MB/s]
# Ultralytics 8.3.169 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !cp -r "/content/runs/detect" "/content/drive/MyDrive/"
